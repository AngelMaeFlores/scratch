# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\lezle a. tino\anaconda3\lib\site-packages (2.2.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\lezle a. tino\anaconda3\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\lezle a. tino\anaconda3\lib\site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six in c:\users\lezle a. tino\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\lezle a. tino\anaconda3\lib\site-packages (3.9.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\lezle a. tino\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\lezle a. tino\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
student_routine= {
    'course':np.random.choice(['Engineering','Education','Nursing','Psychology'],100),
    'hours_studied':np.round(np.random.normal(12,5,100),2),
    'sleep_hours':np.round(np.random.normal(8,5,100),2),
    'exam_score':np.round(np.random.uniform(50,100,100),2),
}

df=pd.DataFrame(student_routine)
df.to_csv('hours_studied_data.csv',index=False)

# %%
df=pd.read_csv('hours_studied_data.csv')
print("Original Data Shape:",df.shape)
# Out:
# Original Data Shape: (100, 4)

# %%
df.loc[np.random.choice(df.index,10),'hours_studied']=np.nan
df.loc[np.random.choice(df.index,5),'sleep_hours']=np.nan

# %%
df.to_csv('hours_studied_data_miss.csv',index=False)

# %%
df=pd.read_csv('hours_studied_data_miss.csv')
print("Original Data Shape:",df.shape)
df['hours_studied']=df['hours_studied'].fillna(df['hours_studied'].mean())
df=df.dropna(subset=['sleep_hours'])
print("Cleaned Data Shape:",df.shape)
df.to_csv('hours_studied_data_cleac.csv',index=False)
# Out:
# Original Data Shape: (100, 4)
# Cleaned Data Shape: (96, 4)

# %%
#Numpy
hours_studied=df['hours_studied'].to_numpy()
sleep_hours=df['sleep_hours'].to_numpy()
correlation=np.corrcoef(hours_studied,sleep_hours)[0,1]
print(f"Correlation between hours studied and sleep hours:{correlation:.2f}")
# Out:
# Correlation between hours studied and sleep hours:-0.01

# %%
#Scipy
Engineering_hours_studied=df[df['course']=='Engineering']['hours_studied']
Nursing_hours_studied=df[df['course']=='Nursing']['hours_studied']
t_stat,p_value=stats.ttest_ind(Engineering_hours_studied,Nursing_hours_studied)
print(f"T-test between Engineering and Nursing hours studied:t={t_stat:.2f},p={p_value:3f}")
# Out:
# T-test between Engineering and Nursing hours studied:t=-0.08,p=0.938153

# %%
 #Statsmodels
X=sm.add_constant(df['sleep_hours'])
model=sm.OLS(df['hours_studied'],X).fit()
print("\nlinear Regression Summary:")
print(model.summary())
# Out:
# linear Regression Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          hours_studied   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                  0.003452
# Date:                Wed, 07 May 2025   Prob (F-statistic):              0.953
# Time:                        16:50:32   Log-Likelihood:                -287.41
# No. Observations:                  96   AIC:                             578.8
# Df Residuals:                      94   BIC:                             583.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          11.9129      0.919     12.957      0.000      10.087      13.738
# sleep_hours    -0.0060      0.102     -0.059      0.953      -0.209       0.197
# ==============================================================================
# Omnibus:                        1.749   Durbin-Watson:                   2.139
# Prob(Omnibus):                  0.417   Jarque-Bera (JB):                1.762
# Skew:                          -0.268   Prob(JB):                        0.414
# Kurtosis:                       2.608   Cond. No.                         16.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Visualisation(Linear Registration) via Matplotlib
plt.figure(figsize=(8,6))
plt.scatter(df['sleep_hours'],df['hours_studied'],alpha=0.5,label='Data')
x_range=np.linspace(df['sleep_hours'].min(),df['sleep_hours'].max(),100)
y_pred=model.params.iloc[0]+model.params.iloc[1]*x_range
plt.plot(x_range,y_pred,color='orange',label='Regression Line')
plt.title('Hours studied vs Sleep hours')
plt.ylabel('hours(hr)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Statistical visualisation(Boslot?Heatmap) via Seaborn
plt.figure(figsize=(8,6))
sns.boxplot(x='hours_studied',y='exam_score',data=df)
plt.title('Effect of Hours studied by Exam score')
plt.savefig('hours_studied_by_exam_score.png')
plt.close()
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.savefig('correlation_heatmap.png')
plt.show()
